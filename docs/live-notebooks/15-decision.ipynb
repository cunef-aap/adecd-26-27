# %% [markdown]
# # Del valor puntual a la decisión
#
# Costes asimétricos, cuantiles e intervalos conformes
#
# > **Capítulo en construcción — semana 15**
# >
# > Se escribe en septiembre. Publicado como esqueleto para que el índice del sitio esté completo desde el primer día.
#
# ## Por qué estamos aquí

# %% [raw]
# <!-- TODO: un párrafo enlazando con el capítulo anterior. -->

# %% [markdown]
# ## De dónde sale el material
#
# -   Chodrow `chapters/12-decision-theory.qmd`: portar el **argumento** (coste como criterio de selección de modelo, no como apéndice) de clasificación a regresión.
# -   Angelopoulos & Bates para conformal split.
#
# ## Resultados que deben aparecer
#
# -   El minimizador de $\mathbb{E}\!\left[ \left\lvert Y-c \right\rvert \right]$ es la mediana ⟹ pérdida pinball ⟹ regresión cuantílica. Completa **?@prp-laplace-mae**.
# -   **Conformal split como cálculo examinable**: ordenar los residuos de calibración, tomar el $\lceil(1-\alpha)(n_{\mathrm{cal}}+1)\rceil$-ésimo, dar $\hat{y}\pm \hat{q}$.
# -   Comparar la anchura del intervalo con $\hat{\sigma}$ del capítulo 2: **ningún modelo baja del suelo de ruido**. Cierre del hilo.
# -   Estado del arte honesto + cierre ético con marco europeo (EU AI Act, RGPD).
#
# ## Ejercicios

# %% [raw]
# <!-- TODO: 4-6 ejercicios con solución plegable. -->

# %% [markdown]
# ## Qué llevarte

# %% [raw]
# <!-- TODO: 3 viñetas. -->
