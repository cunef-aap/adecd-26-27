# %% [markdown]
# # Métodos no lineales: bases, splines y núcleos
#
# No lineal en x no significa no lineal en w
#
# > **Capítulo en construcción — semana 10**
# >
# > Se escribe en septiembre. Publicado como esqueleto para que el índice del sitio esté completo desde el primer día.
#
# ## Por qué estamos aquí

# %% [raw]
# <!-- TODO: un párrafo enlazando con el capítulo anterior. -->

# %% [markdown]
# ## De dónde sale el material
#
# -   Chodrow `chapters/06-regularization.qmd`, sección de expansión de bases.
# -   Datos de demanda eléctrica horaria española para la estacionalidad.
#
# ## Resultados que deben aparecer
#
# -   **El movimiento unificador, como teorema**: si $f(\mathbf{x})=\boldsymbol{w}^{\mathsf{T}}\varphi(\mathbf{x})$ el modelo sigue siendo lineal en $\boldsymbol{w}$; sustituir $\mathbf{X}$ por $\boldsymbol{\Phi}$ y **todo** lo demostrado en los capítulos 3, 4, 6, 7 y 8 sobrevive literalmente. Enunciarlo y demostrarlo así.
# -   Polinomios y su patología en los bordes; splines cúbicos y nudos; bases gaussianas.
# -   k-NN y la maldición de la dimensionalidad.
#
# ## Ejercicios

# %% [raw]
# <!-- TODO: 4-6 ejercicios con solución plegable. -->

# %% [markdown]
# ## Qué llevarte

# %% [raw]
# <!-- TODO: 3 viñetas. -->
