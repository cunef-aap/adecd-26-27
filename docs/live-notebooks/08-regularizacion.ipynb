# %% [markdown]
# # Regularización: ridge, lasso y el prior
#
# La semana con más contenido bayesiano del curso
#
# > **Capítulo en construcción — semana 8**
# >
# > Se escribe en septiembre. Publicado como esqueleto para que el índice del sitio esté completo desde el primer día.
#
# ## Por qué estamos aquí

# %% [raw]
# <!-- TODO: un párrafo enlazando con el capítulo anterior. -->

# %% [markdown]
# ## De dónde sale el material
#
# -   **`curso-ml-R/Rmd/04-regression`** — la mina principal. Lasso, ridge, elastic net, la interpretación bayesiana, y sobre todo el **descenso coordinado con el operador soft-thresholding, derivado paso a paso con análisis de subdiferencial**. Ya en español, ya en notación \`w\`.
# -   Chodrow `chapters/06-regularization.qmd` para la motivación desde bases y validación.
# -   ⚠ Autoría: Alberto Torres Barrán. Pedir permiso antes de publicar prosa literal.
#
# ## Resultados que deben aparecer
#
# -   Ridge cerrado: $\hat{\boldsymbol{w}}_{\lambda}= (\mathbf{X}^{\mathsf{T}}\mathbf{X}+ n\lambda\mathbf{I})^{-1}\mathbf{X}^{\mathsf{T}}\mathbf{y}$, invertible para todo $\lambda>0$. Sale de **?@thm-gradiente-matricial** en dos líneas.
# -   **Ridge = MAP con prior gaussiano; lasso = MAP con prior de Laplace.** El pago del hilo abierto en **?@def-verosimilitud**. Chodrow monta el andamiaje y nunca lo cobra.
# -   **Soft-thresholding con diseño ortonormal**: $w_j= \mathop{\mathrm{sign}}(w_j^{\text{MCO}})\left( \left\lvert w_j^{\text{MCO}} \right\rvert-\lambda \right)_{+}$. La única demostración honesta de por qué L1 da ceros exactos y L2 no.
# -   Tabla de traducción $\lambda$ ↔ \`alpha=\` de scikit-learn. La colisión que más confunde.
#
# ## Ejercicios

# %% [raw]
# <!-- TODO: 4-6 ejercicios con solución plegable. -->

# %% [markdown]
# ## Qué llevarte

# %% [raw]
# <!-- TODO: 3 viñetas. -->
