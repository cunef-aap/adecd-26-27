# %% [markdown]
# # Sesgo, varianza y ruido
#
# Por qué el error de test tiene un suelo que ningún modelo cruza
#
# > **Capítulo en construcción — semana 7**
# >
# > Se escribe en septiembre. Publicado como esqueleto para que el índice del sitio esté completo desde el primer día.
#
# ## Por qué estamos aquí

# %% [raw]
# <!-- TODO: un párrafo enlazando con el capítulo anterior. -->

# %% [markdown]
# ## De dónde sale el material
#
# -   Chodrow `chapters/07-bias-variance.qmd` — descomposición completa, con la forma *no condicionada* $E = \mathrm{Var}\!\left( \hat{Y} \right) + (\hat\mu-\mu)^2 + \mathrm{Var}\!\left( Y \right)$. Más simple que la de ISLR/ESL; elegir una y avisar de que verán la otra.
# -   `curso-ml-R/Rmd/02-supervised` sl. 15-16 (descomposición del error: optimización / estimación / aproximación) y sl. 21-24.
# -   **Cortado de Chodrow**: doble descenso y polinomios de Legendre.
#
# ## Resultados que deben aparecer
#
# -   Def. sobreajuste (ya está en **?@def-sobreajuste**; aquí se retoma con aparato).
# -   Teo. descomposición sesgo-varianza-ruido. Demostración por sumar y restar.
# -   El término de ruido **es** $\hat{\sigma}^2$ de **?@thm-perfilado-sigma**: cuarta aparición del hilo.
# -   Simulación Monte Carlo: 500 conjuntos, 500 rectas, los tres términos estimados.
#
# ## Ejercicios

# %% [raw]
# <!-- TODO: 4-6 ejercicios con solución plegable. -->

# %% [markdown]
# ## Qué llevarte

# %% [raw]
# <!-- TODO: 3 viñetas. -->
