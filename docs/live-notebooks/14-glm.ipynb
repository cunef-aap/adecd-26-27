# %% [markdown]
# # Cuando el ruido no es gaussiano: GLM
#
# Volver al paso 1 de la receta y cambiar la distribución
#
# > **Capítulo en construcción — semana 14**
# >
# > Se escribe en septiembre. Publicado como esqueleto para que el índice del sitio esté completo desde el primer día.
#
# ## Por qué estamos aquí

# %% [raw]
# <!-- TODO: un párrafo enlazando con el capítulo anterior. -->

# %% [markdown]
# ## De dónde sale el material
#
# -   `curso-ml-R/Rmd/02-supervised` sl. 43-54 (logística, Newton-Raphson **derivado**, IRLS).
# -   `curso-ml-R/Rmd/04-regression` sl. 3-6 (GLM, ejemplo Poisson).
# -   ⚠ La regresión logística se menciona **una vez** como miembro Bernoulli del catálogo de enlaces y **no se evalúa**: es de G249.
#
# ## Resultados que deben aparecer
#
# -   Si $y$ es un conteo, el modelo gaussiano predice negativos y asume varianza constante: ambas cosas falsas.
# -   Poisson con enlace logarítmico; log-verosimilitud y su gradiente $\mathbf{X}^{\mathsf{T}}(\mathbf{y}-\boldsymbol\mu)$ — **misma forma que **?@thm-gradiente-matricial****, otra $\mu$.
# -   Desvianza como pérdida. Tabla de familias y enlaces (cierra (**rem-catalogo?**)).
# -   Interpretación multiplicativa de los coeficientes.
#
# ## Ejercicios

# %% [raw]
# <!-- TODO: 4-6 ejercicios con solución plegable. -->

# %% [markdown]
# ## Qué llevarte

# %% [raw]
# <!-- TODO: 3 viñetas. -->
